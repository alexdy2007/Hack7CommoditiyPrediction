# %%
import pandas as pd
from pandas import Series
import os

# %%
# NOTEBOOK SETTINGS
# %precision 2
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
cwd = os.getcwd()
material_price_file = cwd + os.sep + "data" + os.sep + "Material Requisition deleted rows.xlsx"

# %%
# READ IN DATA
df_materials = pd.read_excel(material_price_file)

# %%
# REMOVE NONE NUMBERICAL ROWS FROM TOTAL COST
def is_number(x):
    try:
        float(x)
        return True
    except Exception as e:
        return False


df_materials_1 = df_materials[df_materials['Total_Cost'].map(is_number) == True]

# %%
def groupby_column_running_pc_spend(df, column_to_group_by):
    column_to_group_by = "Category"
    df["Total_Cost"] = pd.to_numeric(df["Total_Cost"], downcast='float')
    sub_columns = [column_to_group_by, "Total_Cost"]
    df_sub = df[sub_columns]
    grouped_by_category = (df_sub.groupby(column_to_group_by,group_keys=True).sum())
    grouped_by_category_descending = grouped_by_category.sort_values("Total_Cost", ascending=False)
    return grouped_by_category_descending

def pc_spend_of_col(df, column):
    col_name = "CUMLATIVE_" + column
    total_pc_col_name = column + "_PC"
    df[col_name] = df["Total_Cost"].cumsum()
    df[total_pc_col_name] =  grouped_by_category_desc[col_name] / total_spend
    return df
    
    
grouped_by_category_desc = groupby_column_running_pc_spend(df_materials_1, column_to_group_by = "Category")
grouped_by_category_desc1 = pc_spend_of_col(grouped_by_category_desc, "Total_Cost")
# Out:
# <ipython-input-132-527f95a2a01a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Total_Cost"] = pd.to_numeric(df["Total_Cost"], downcast='float')

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
# Add Category Count and spend per datapoint
df_category_count = df_materials_1[column_to_group_by].value_counts()
df_category_count = df_category_count.rename("CATEGORY_COUNT")
grouped_by_category_desc_2 = grouped_by_category_desc1.join(df_category_count)
grouped_by_category_desc_2["TOTAL_SPEND_PER_DATA_POINT"] = grouped_by_category_desc_1["Total_Cost"]/grouped_by_category_desc_1["CATEGORY_COUNT"]

# %%
grouped_by_category_desc_2.sort_values("TOTAL_SPEND_PER_DATA_POINT", ascending=False)
# Out:
#                                            Total_Cost  CUMLATIVE_Total_Cost  \
# Category
# Gas Oil                                   1850618.375          50063752.000
# Aggregate                                12114678.000          43897376.000
# Concrete Hard Landscaping (Kerbs, Slabs) 31782698.000          31782698.000
# Fuel                                       904264.188          57524568.000
# Electrical                                1512034.500          51575788.000
# Ready Mixed Concrete                       336281.000          60957940.000
# Blocks and Bricks                         1322129.500          54239932.000
# Geotextiles                                454637.062          60214776.000
# Office Supplies                            810295.000          59228144.000
# Flow Control                                98722.523          62900912.000
# Concrete Accessories                      1165216.875          56620304.000
# Waste (General)                            200820.406          62004608.000
# Rebar and Mesh                             291420.469          61554312.000
# Training                                   163534.359          62697360.000
# Professional Services                      893278.375          58417848.000
# Not Sure                                   531997.375          59760140.000
# Miscellaneous                             4315756.000          48213132.000
# Fixings and Fasteners                      304952.906          61262892.000
# Tanks and Interceptors                      26632.611          63077292.000
# Ductile Drainage                           249475.203          61803788.000
# Concrete Drainage                         1215156.625          55455088.000
# Damage Charges                             104829.562          62802188.000
# Plastic Drainage                          1342016.375          52917804.000
# Waste (Recycling)                           23810.000          63101104.000
# Laboratory Equipment / Certification        73779.539          62974692.000
# Builders Merchants (General)               406884.594          60621660.000
# Surveying Consumables                      172767.359          62533824.000
# Timber Products                             49316.762          63024008.000
# PPE                                        180778.484          62185388.000
# Janitorial                                  26652.430          63050660.000
# Small Tools (Consumables)                  175669.734          62361056.000
# Reinforcement                                2153.000          63103256.000
#
#                                           Total_Cost_PC  CATEGORY_COUNT  \
# Category
# Gas Oil                                           0.793              20
# Aggregate                                         0.696             199
# Concrete Hard Landscaping (Kerbs, Slabs)          0.504             832
# Fuel                                              0.912              27
# Electrical                                        0.817              67
# Ready Mixed Concrete                              0.966              21
# Blocks and Bricks                                 0.860             126
# Geotextiles                                       0.954              90
# Office Supplies                                   0.939             161
# Flow Control                                      0.997              30
# Concrete Accessories                              0.897             370
# Waste (General)                                   0.983              73
# Rebar and Mesh                                    0.975             113
# Training                                          0.994              64
# Professional Services                             0.926             353
# Not Sure                                          0.947             233
# Miscellaneous                                     0.764            1896
# Fixings and Fasteners                             0.971             183
# Tanks and Interceptors                            1.000              16
# Ductile Drainage                                  0.979             191
# Concrete Drainage                                 0.879             994
# Damage Charges                                    0.995              95
# Plastic Drainage                                  0.839            1238
# Waste (Recycling)                                 1.000              32
# Laboratory Equipment / Certification              0.998             114
# Builders Merchants (General)                      0.961             643
# Surveying Consumables                             0.991             294
# Timber Products                                   0.999             108
# PPE                                               0.985             455
# Janitorial                                        0.999              83
# Small Tools (Consumables)                         0.988             821
# Reinforcement                                     1.000              43
#
#                                           TOTAL_SPEND_PER_DATA_POINT
# Category
# Gas Oil                                                    92530.919
# Aggregate                                                  60877.779
# Concrete Hard Landscaping (Kerbs, Slabs)                   38200.358
# Fuel                                                       33491.266
# Electrical                                                 22567.679
# Ready Mixed Concrete                                       16013.381
# Blocks and Bricks                                          10493.091
# Geotextiles                                                 5051.523
# Office Supplies                                             5032.888
# Flow Control                                                3290.751
# Concrete Accessories                                        3149.235
# Waste (General)                                             2750.964
# Rebar and Mesh                                              2578.942
# Training                                                    2555.224
# Professional Services                                       2530.534
# Not Sure                                                    2283.251
# Miscellaneous                                               2276.243
# Fixings and Fasteners                                       1666.409
# Tanks and Interceptors                                      1664.538
# Ductile Drainage                                            1306.153
# Concrete Drainage                                           1222.492
# Damage Charges                                              1103.469
# Plastic Drainage                                            1084.020
# Waste (Recycling)                                            744.062
# Laboratory Equipment / Certification                         647.189
# Builders Merchants (General)                                 632.791
# Surveying Consumables                                        587.644
# Timber Products                                              456.637
# PPE                                                          397.315
# Janitorial                                                   321.114
# Small Tools (Consumables)                                    213.970
# Reinforcement                                                 50.070
